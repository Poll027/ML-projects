# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Advertising.csv')

# %%
X = df.drop('sales', axis=1)
y = df['sales']

# %%
potential_spends = np.linspace(0, 500, 100).reshape(-1, 1)

# %%
X = df.drop

# %%
from sklearn.linear_model import LinearRegression

# %%
potential_spends = np.linspace(0, 500, 100).reshape(-1, 1)

# %%
predicted_sales = 0.04868788 * potential_pends + 4.24302822

# %%
plt.plot(potential_spends, predicted_sales)
sns.scatterplot(x='total_spend', y='sales', data=df)
# Out:
# <Axes: xlabel='total_spend', ylabel='sales'>

# %% [markdown]
# For instance if our total spend was 200

# %%
spend = 200
predicted_sales = 0.04868788 * spend + 4.24302822
predicted_sales
# Out:
# 13.98060422

# %%
poly = PolynomialFeatures(degree=3)

# %%
pot_spend = np.linspace(0, 500, 100)

# %%
pred_sales = 3.07615033e-07*pot_spend**3 + -1.89392449e-04*pot_spend**2 + 8.20886302e-02*pot_spend + 2.70495053e+00

# %%
plt.plot(pot_spend, pred_sales)
sns.scatterplot(x='total_spend', y='sales', data=df)
# Out:
# <Axes: xlabel='total_spend', ylabel='sales'>

# %%
X = df.drop('sales', axis=1)

# %%
y = df['sales']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
test_predictions = model.predict(X_test)
test_predictions
# Out:
# array([15.74131332, 19.61062568, 11.44888935, 17.00819787,  9.17285676,
#         7.01248287, 20.28992463, 17.29953992,  9.77584467, 19.22194224,
#        12.40503154, 13.89234998, 13.72541098, 21.28794031, 18.42456638,
#         9.98198406, 15.55228966,  7.68913693,  7.55614992, 20.40311209,
#         7.79215204, 18.24214098, 24.68631904, 22.82199068,  7.97962085,
#        12.65207264, 21.46925937,  8.05228573, 12.42315981, 12.50719678,
#        10.77757812, 19.24460093, 10.070269  ,  6.70779999, 17.31492147,
#         7.76764327,  9.25393336,  8.27834697, 10.58105585, 10.63591128,
#        13.01002595,  9.77192057, 10.21469861,  8.04572042, 11.5671075 ,
#        10.08368001,  8.99806574, 16.25388914, 13.23942315, 20.81493419,
#        12.49727439, 13.96615898, 17.56285075, 11.14537013, 12.56261468,
#         5.50870279, 23.29465134, 12.62409688, 18.77399978, 15.18785675])

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
df['sales'].mean()
# Out:
# 14.0225

# %%
sns.histplot(data=df, x='sales', bins=20)
# Out:
# <Axes: xlabel='sales', ylabel='Count'>

# %%
mean_absolute_error(y_test, test_predictions)
# Out:
# 1.2137457736144817

# %%
mean_squared_error(y_test, test_predictions)
# Out:
# 2.298716697886383

# %%
np.sqrt(mean_squared_error(y_test, test_predictions))
# Out:
# 1.5161519375993895

# %%
test_residuals = y_test - test_predictions

# %%
sns.scatterplot(x=y_test, y=test_residuals)
plt.axhline(y=0, color='red', ls='--')

# %%
final_model = LinearRegression()
final_model.fit(X, y)
# Out:
# LinearRegression()

# %%
final_model.coef_
# Out:
# array([ 0.04576465,  0.18853002, -0.00103749])

# %%
from joblib import dump, load

# %%
dump(final_model, 'final_sales_model.joblib')
# Out:
# ['final_sales_model.joblib']

# %%
loaded_model = load('final_sales_model.joblib')

# %%
loaded_model.coef_
# Out:
# array([ 0.04576465,  0.18853002, -0.00103749])

# %%
X.head()
# Out:
#       TV  radio  newspaper
# 0  230.1   37.8       69.2
# 1   44.5   39.3       45.1
# 2   17.2   45.9       69.3
# 3  151.5   41.3       58.5
# 4  180.8   10.8       58.4

# %%
campaign = [[149,22,12]]

# %%
loaded_model.predict(campaign)
# Out:
# c:\Users\Folajuwon\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([13.893032])

# %%
df = pd.read_csv('advertising.csv')

# %%
X = df.drop('sales', axis=1)
y = df['sales']

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
polynomial_converter = PolynomialFeatures(degree = 2, include_bias=False)

# %%
polynomial_converter.fit(X)
# Out:
# PolynomialFeatures(include_bias=False)

# %%
poly_features = polynomial_converter.transform(X)

# %%
poly_features[0]
# Out:
# array([2.301000e+02, 3.780000e+01, 6.920000e+01, 5.294601e+04,
#        8.697780e+03, 1.592292e+04, 1.428840e+03, 2.615760e+03,
#        4.788640e+03])

# %%
from sklearn.model_selection import  train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(poly_features, y, test_size=0.3, random_state=101)

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
test_predictions = model.predict(X_test)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
MAE = mean_absolute_error(y_test, test_predictions)
MSE = mean_squared_error(y_test, test_predictions)
RMSE = np.sqrt(MSE)

# %%
train_rmse_errors = []
test_rmse_errors = []

for d in range(1,10):

    poly_converter = PolynomialFeatures(degree=d, include_bias=False)
    poly_features = poly_converter.fit_transform(X)

    X_train, X_test, y_train, y_test = train_test_split(poly_features, y, test_size=0.3, random_state=101)

    model = LinearRegression()
    model.fit(X_train, y_train)

    train_pred = model.predict(X_train)
    test_pred = model.predict(X_test)

    train_rmse = np.sqrt(mean_squared_error(y_train, train_pred))
    test_rmse = np.sqrt(mean_squared_error(y_test, test_pred))

    train_rmse_errors.append(train_rmse)
    test_rmse_errors.append(test_rmse)

# %%
train_rmse_errors
# Out:
# [1.734594124329376,
#  0.5879574085292232,
#  0.4339344356902066,
#  0.35170836883993495,
#  0.2509342951990972,
#  0.1971254009841768,
#  5.421422348088463,
#  0.1426544837726474,
#  0.16675345956185658]

# %%
test_rmse_errors
# Out:
# [1.5161519375993877,
#  0.6646431757269152,
#  0.5803286825156331,
#  0.5077742623872589,
#  2.5758247707699113,
#  4.492670773896812,
#  1381.4040685804796,
#  4449.568027403435,
#  95893.02658330933]

# %%
plt.plot(range(1,6), train_rmse_errors[:5], label='TRAIN')
plt.plot(range(1,6), test_rmse_errors[:5], label='TEST')
plt.legend()
plt.xlabel('Degree of Polynomial')
plt.ylabel('RMSE')
# Out:
# Text(0, 0.5, 'RMSE')

# %%
final_poly_converter = PolynomialFeatures(degree=3, include_bias=False)

# %%
final_model = LinearRegression()

# %%
fully_converted_X = final_poly_converter.fit_transform(X)
final_model.fit(fully_converted_X, y)
# Out:
# LinearRegression()

# %%
from joblib import dump, load

# %%
dump(final_poly_converter, 'final_converter.joblib')
# Out:
# ['final_converter.joblib']

# %%
loaded_conve = load('final_converter.joblib')

# %%
loaded_model = load('final_poly_model.joblib')
# Out:
# c:\Users\Folajuwon\anaconda3\Lib\site-packages\sklearn\base.py:376: InconsistentVersionWarning: Trying to unpickle estimator LinearRegression from version 0.23.2 when using version 1.5.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(

# %%
campaign = [[149,22,12]]

# %%
transformed_data = loaded_conve.fit_transform(campaign)

# %%
loaded_model.predict(transformed_data)
# Out:
# array([14.64501014])
